# %% [markdown]
# # 🔑 Chapter 2: The Two-Key Turn (AND / OR)
# ### Double Checking
# Sometimes, checking one thing isn't enough. Imagine a nuclear submarine. To launch a missile, **two** people have to turn their keys at the exact same time.
#
# We call these **Logical Operators**:
# 1.  **`and`**: BOTH things must be True.
# 2.  **`or`**: EITHER thing can be True.

# %% [markdown]
# ### The "AND" Check (Strict)
# The robot will only move if it has battery **AND** the path is clear.

# %%
battery = 60
path_is_clear = True

# Try changing one of these to False and see what happens!
if battery > 0 and path_is_clear == True:
    print("Systems Go! Moving Forward.")
else:
    print("Cannot move. Check battery or path.")
# Out:
# Systems Go! Moving Forward.

# %% [markdown]
# ### The "OR" Check (Flexible)
# The robot should stop if it hits a wall **OR** if the emergency button is pressed.

# %%
hit_wall = False
emergency_button = True

if hit_wall == True or emergency_button == True:
    print("STOPPING ROBOT IMMEDIATELY!")
else:
    print("Driving...")

# %% [markdown]
# ### 🛠️ Robot Activity: "The Safe Driver"
# **Your Mission:**
# Write the code for the robot's Claw Arm. It is only allowed to close IF:
# 1.  The robot is stopped (`is_moving == False`)
# 2.  **AND** the object is detected (`object_seen == True`)
#
# Set your variables and write the `if` statement.

# %%
# --- WRITE YOUR MISSION CODE BELOW ---

# 1. Set variables (try different combinations)
is_moving = False
object_seen = True

# 2. Write the AND Logic
if is_moving == False or object_seen == True:
    print("Claw arm closed")
else:
    print("Claw arm open.")
# Out:
# Claw arm closed

# %%
### 🛠️ Grace Activity: "The Safe Eater"
#**Your Mission:**
#Write the code for the dinner. It is only allowed to eat IF:
#1.  grace is not moving (`is_moving == False`)
#2.  **AND** the food is detected (`food_seen == True`)

#Set your variables and write the `if` statement.

# %%
is_moving = True
food_seen = True


if is_moving == False and food_seen == True:
    print("Grace allowed to eat.")
else:
    print("Grace not allowed to eat.")
# Out:
# Grace not allowed to eat.

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Master Lock:**
# Create three variables: `key_1`, `key_2`, `key_3`. Set them to `True` or `False`.
# Write an `if` statement that only unlocks if ALL THREE are `True`.
# (`if key_1 and key_2 and key_3:`)

# %%
key_1 = True
key_2 = True
key_3 = True

if key_1 and key_2 and key_3:
    print("unlock")
# Out:
# unlock
