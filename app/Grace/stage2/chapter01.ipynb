# %% [markdown]
# # 🚥 Chapter 1: The Traffic Light (Elif)
# ### It's Not Just Black and White
# In Phase 1, we learned `if` and `else`. That works great for "Yes" or "No" questions.
#
# But what if we have **many** options? Like a traffic light:
# * **Red** = Stop
# * **Green** = Go
# * **Yellow** = Slow Down
#
# We use the command `elif` (which stands for "Else If") to check multiple options in a row.

# %% [markdown]
# ### How ELIF Works
# The computer checks them one by one, from top to bottom. As soon as it finds one that is `True`, it runs that code and **skips the rest**.

# %%
traffic_light_color = "Green"

if traffic_light_color == "Red":
    print("STOP! Danger!")
elif traffic_light_color == "Yellow":
    print("Slow down...")
elif traffic_light_color == "Green":
    print("GO! GO! GO!")
else:
    print("Light is broken. Be careful!")
# Out:
# GO! GO! GO!

# %% [markdown]
# ### 🛠️ Robot Activity: "The Color Sorter"
# **Your Mission:**
# Your robot has a Color Sensor looking at the floor. It needs to react differently to different colored tiles.
#
# 1.  Create a variable `floor_color` and set it to `"Blue"`.
# 2.  Write an `if` / `elif` / `else` chain:
#     * If **Red**: Print "Lava detected! Stop!"
#     * If **Blue**: Print "Water detected! Swim!"
#     * If **Green**: Print "Grass detected! Drive fast!"
#     * **Else**: Print "Unknown ground. Drive slowly."

# %%
# --- WRITE YOUR MISSION CODE BELOW ---

# 1. Set the floor color
floor_color = "Blue"

# 2. Write the Logic Chain (If / Elif / Elif / Else)
if floor_color == "Red":
    print("Lava detected!Stop!")
elif floor_color == "Blue":
    print("Water detected!Swim!")
elif floor_color == "Green":
    print("Grass detected!Drive fast!")
else:
    print("Unknown ground.Drive slowly.")
# Out:
# Water detected!Swim!

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Speed Limit:**
# The robot reads a speed limit sign (integer).
# * `limit = 50`
# * If limit is **0**: Print "Halt."
# * Elif limit is **under (<) 20**: Print "School Zone - Slow."
# * Elif limit is **over (>) 60**: Print "Highway - Turbo Mode!"
# * Else: Print "Normal Cruise."

# %%
limit = 20
if limit == 0:
    print("Halt")
elif limit < 20:
    print("School Zone - Slow.")
elif limit > 60:
    print("Highway - Turbo Mode!")
else:
    print("Normal Cruise.")
# Out:
# Normal Cruise.
