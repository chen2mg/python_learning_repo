# %% [markdown]
# # 🎛️ Chapter 8: The Universal Driver (Parameters)
# ### One Function, Many Uses
# In Phase 1, we wrote simple functions like `drive_forward()`.
# But what if we want to drive forward **Fast** sometimes, and **Slow** other times?
#
# We don't want to write two different functions. We want ONE function that accepts options.
# We call these options **Parameters** (or Arguments).

# %%
# Example: A function that takes a Name as an input
def say_hello(name):
    print("Hello Commander", name)

# Now we can use it for anyone!
say_hello("Iron Giant")
say_hello("Wall-E")
# Out:
# Hello Commander Iron Giant
# Hello Commander Wall-E

# %% [markdown]
# ### 🛠️ Robot Activity: "The Precise Navigator"
# **Your Mission:**
# Write a smart drive function that knows how fast to go and how far to go.
#
# 1.  Define a function: `def drive(speed, distance):`.
# 2.  Inside, print: "Setting Motors to speed: " and the `speed` variable.
# 3.  Inside, print: "Moving for (mm): " and the `distance` variable.
# 4.  **Test it!** Call the function 3 times with different numbers:
#     * `drive(50, 100)`  (Slow and Short)
#     * `drive(100, 500)` (Fast and Long)
#     * `drive(0, 0)`     (Stop)

# %%
# --- WRITE YOUR MISSION CODE BELOW ---

# 1. Define the function with 2 parameters
def drive(speed, distance):
    print("Setting Motors to speed:")
    print(speed)
    print("Moving for (mm):")
    print(distance)
# 2. Call the function (Test 1)
drive(50, 100)
drive(100, 500)
# 3. Call the function (Test 2)
drive(0, 0)
# Out:
# Setting Motors to speed:
# 50
# Moving for (mm):
# 100
# Setting Motors to speed:
# 100
# Moving for (mm):
# 500
# Setting Motors to speed:
# 0
# Moving for (mm):
# 0

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Turn Master:**
# Write a function called `turn(direction, degrees)`.
# It should be able to handle: `turn("Left", 90)` or `turn("Right", 45)`.
# Use an `if` statement inside to print which way it is turning.

# %%
def turn(direction, degrees):
    print("Turning:")
    print(direction)
    if direction < 180:
        print("Right")
    else:
        print("Left")
    print("Speed is:")
    print(degrees)
turn(122, 34)
# Out:
# Turning:
# 122
# Right
# Speed is:
# 34
