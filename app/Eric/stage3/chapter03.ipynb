# %% [markdown]
# # 🤖 Chapter 3: Robot Actions (Behavior)
#
# So far, our robots can **remember things** (attributes)...
#
# But they can't DO anything yet 😴
#
# Today we will fix that!
#
# We will learn about **Methods (Functions inside a class)**.
#
# 👉 Methods tell the robot what actions to perform!

# %% [markdown]
# ## 🧠 What is a Method?
#
# A **method** is a function inside a class.
#
# Think of it like:
# - Attributes = what the robot *has*
# - Methods = what the robot *does*
#
# Examples:
# - drive forward 🚗
# - detect distance 📏
# - check bumper 🔘

# %% [markdown]
# ## ⚙️ Let's Build a Robot with Actions

# %%
class Robot:
    def __init__(self, name):
        self.name = name

    # Method: drive forward
    def drive_forward(self):
        print(self.name, "is driving forward 🚗")

    # Method: detect distance
    def detect_front_distance(self):
        print(self.name, "is checking distance 📏")
        return 100  # pretend distance is 100 mm

    # Method: check bumper
    def is_bumper_pressed(self):
        print(self.name, "is checking bumper 🔘")
        return False

# Create robot
robot = Robot("Huey")

# Call methods
whatisthis = robot.drive_forward()
distance = robot.detect_front_distance()
print("Distance:", distance)

pressed = robot.is_bumper_pressed()
print("Bumper pressed:", pressed)
# Out:
# Huey is driving forward 🚗
# Huey is checking distance 📏
# Distance: 100
# Huey is checking bumper 🔘
# Bumper pressed: False

# %%
print(whatisthis)
# Out:
# None

# %%
# a, b are parameters, parameters are value pass to function
# function has three key components
# 1. function name: add
# 2. function parameters: a, b, this is optional, input
# 3. function return value: c, this is optional, output
def add():
    #c= a+b
    return 100

result = add()
print(result)
# Out:
# 100

# %% [markdown]
# 👉 Notice:
# - We use `robot.method_name()` to call a method
# - Methods can **return values** (like distance)

# %% [markdown]
# ## 🎮 Make Decisions (Robot Logic)
#
# Now let's make the robot **think**!
#
# If something is in front → STOP
# Otherwise → MOVE

# %%
distance = robot.detect_front_distance()

if distance < 50:
    print("Too close! Stop! 🛑")
else:
    robot.drive_forward()
# Out:
# Huey is checking distance 📏
# Huey is driving forward 🚗

# %% [markdown]
# 👉 This is how real robots make decisions!

# %% [markdown]
# ## 🔌 VEX-Style Robot Example
#
# Now let's make it look more like a real VEX robot!

# %%
# Simulated VEX devices
class Distance:
    def object_distance(self):
        return 80  # pretend value

class Bumper:
    def pressing(self):
        return False

class Robot:
    def __init__(self, name):
        self.name = name
        self.distance = Distance()
        self.bumper = Bumper()

    def drive_forward(self):
        print(self.name, "drives forward 🚗")

    def check_and_move(self):
        if self.distance.object_distance() < 50:
            print("Object detected! Stop! 🛑")
        elif self.bumper.pressing():
            print("Bumper hit! Stop! 🔘")
        else:
            self.drive_forward()

# Test robot
robot = Robot("VEXBot")
robot.check_and_move()
# Out:
# VEXBot drives forward 🚗

# %% [markdown]
# # 🎯 Key Ideas
#
# - Methods = actions
# - Call methods using `robot.method()`
# - Methods can return values
# - Robots use methods + logic to make decisions

# %% [markdown]
# # 🧪 Practice Area
#
# Now it's your turn!
#
# 👉 Complete the robot below:
#
# Tasks:
# 1. Add method `say_hello()`
# 2. Add method `drive_forward()`
# 3. Call both methods

# %%
class Robot:
    def __init__(self, name):
        self.name = name

    # TODO: create say_hello method
    def say_hello(self):
        print("Hello!")
        
    # TODO: create drive_forward method
    def drive_forward(self):
        print("Robot is driving forward...")

# TODO: create robot
robot1 = Robot("Huey")

# TODO: call methods
robot1.say_hello()
robot1.drive_forward()

print("My robot name is: ",robot1.name)
# Out:
# Hello!
# Robot is driving forward...
# My robot name is:  Huey

# %% [markdown]
# 💡 Hint:
# - Use `def method_name(self):`
# - Use `print(self.name, "...")`

# %% [markdown]
# # 🏠 Homework
#
# 🎯 Build a Smart Robot!
#
# Create a class with:
#
# Attributes:
# - name
#
# Methods:
# - drive_forward()
# - detect_front_distance()
# - stop()
#
# Program behavior:
# - If distance < 50 → stop
# - Else → drive forward
#
# ✨ Bonus:
# - Add a method `celebrate()` 🎉
# - Call it when robot moves safely
#
# Have fun bringing your robot to life 🤖✨!

# %%
class Robot:
    def __init__(self, name):
        self.name = name

    def drive_forward(self):
        print("Robot is driving forward...")
    def detect_front_distance(self):
        print("Checking front distance...")
        return 58
    def stop():
        print("Robot is stopping...")

SuperRobot = Robot("Technobyte")

distance = SuperRobot.detect_front_distance()

if distance < 50:
    SuperRobot.stop()
else:
    SuperRobot.drive_forward()
# Out:
# Checking front distance...
# Robot is driving forward...
