# %% [markdown]
# # 🤖 Chapter 2: Robot Specs (State)
#
# Today we will learn how robots **remember things about themselves**!
#
# In programming, we call this **Attributes (Member Variables)**.
#
# Think about a real robot:
# - It has a name 🏷️
# - It has sensors 👀
# - It has parts like wheels ⚙️
#
# All of these are **properties** of the robot.

# %% [markdown]
# ## 🧠 What are Attributes?
#
# Attributes are **things a robot knows about itself**.
#
# Example:
# - name = "Robo1"
# - has a distance sensor
# - has a bumper sensor
#
# We store these inside a class using something called **self**.

# %% [markdown]
# ## 🔑 What is `self`?
#
# `self` means:
#
# 👉 "THIS robot"
#
# Every robot has its **own** data.
#
# So `self.name` means:
# - "this robot's name"
#
# Let's see it in action 👇

# %%
# Define a robot class with attributes
class Robot:
    def __init__(self, name):
        self.name = name  # each robot remembers its own name

# Create two robots
robot1 = Robot("Huey")
robot2 = Robot("Scorpion")

print(robot1.name)
print(robot2.name)
# Out:
# Huey
# Scorpion

# %% [markdown]
# 👉 Even though both robots come from the SAME class,
# they have DIFFERENT names!
#
# That’s the power of `self` 🎉

# %% [markdown]
# ## ⚙️ Adding More Robot Specs
#
# Now let's give our robot more parts!
#
# We will add:
# - brain
# - distance sensor
# - bumper
# - optical sensor

# %%
# Simulated VEX devices (just placeholders for now)
class Brain:
    pass

class Distance:
    pass

class Bumper:
    pass

class Optical:
    pass

# Robot with more attributes
class Robot:
    def __init__(self, name):
        self.name = name
        self.brain = Brain()
        self.distance_sensor = Distance()
        self.bumper = Bumper()
        self.optical = Optical()

# Create a robot
robot = Robot("Huey")

print("Robot name:", robot.name)
print("Has brain:", robot.brain)
print("Has distance sensor:", robot.distance_sensor)
# Out:
# Robot name: Huey
# Has brain: <__main__.Brain object at 0x7fb438f090>
# Has distance sensor: <__main__.Distance object at 0x7fb438f190>

# %% [markdown]
# 👉 Now your robot has **parts and sensors**!
#
# Each robot you create will have its OWN sensors.

# %% [markdown]
# # 🎯 Key Ideas
#
# - Attributes = robot's properties
# - `self` = "this robot"
# - Each object stores its OWN data
#
# Example:
# - `self.name`
# - `self.distance_sensor`

# %% [markdown]
# # 🧪 Practice Area
#
# Now it's your turn!
#
# 👉 Complete the Robot class below:
#
# Tasks:
# 1. Add attribute `name`
# 2. Add attribute `battery_level`
# 3. Create a robot object
# 4. Print its values

# %%
class Robot:
    def __init__(self, name, battery_level):
        # TODO: save name
        self.name = name
        # TODO: save battery level
        self.battery_level = battery_level

# TODO: create a robot
robot = Robot("Clawbot", 85)

# TODO: print robot name
print(robot.name)

# TODO: print battery level
print(robot.battery_level)
# Out:
# Clawbot
# 85

# %% [markdown]
# 💡 Hint:
# - Use `self.name = name`
# - Use `self.battery_level = battery_level`

# %% [markdown]
# # 🏠 Homework
#
# 🎯 Build Your Own Smart Robot!
#
# Write your own program:
#
# 1. Create a class called `SmartRobot`
# 2. Add attributes:
#    - name
#    - color
#    - has_camera (True/False)
#
# 3. Create at least **2 robots** with different values
#
# 4. Print all their information
#
# ✨ Bonus:
# - Add a new attribute: `team_name`
# - Print: "Robot Alpha is in Team RoboPanda!"
#
# Have fun upgrading your robots 🤖✨!

# %%
class SmartRobot:
    def __init__(self, name, color, has_camera):
        self.name = name
        self.color = color
        # self reprsent this class, here the smartrobot
        self.has_camera = has_camera

# what is object
# those are values
Robot1 = SmartRobot("huey", "blue", True)
print("robot name is:",Robot1.name)
print("Sensor Detects:", Robot1.color)
print("Does it have a camera:", Robot1.has_camera)
if Robot1.has_camera == True:
    print("The Robot Has a Camera.")
class dog():
    pass

mina = dog()
macy = dog()
# Out:
# robot name is: huey
# Sensor Detects: blue
# Does it have a camera: True
# The Robot Has Camera.
