# %%
cup = 3
saturday = 28 
money = cup * saturday
loss = 25
print("Emma Earned...")
print(cup * saturday, "$")
print("Emma earned this after applying loss")
print(money - loss, "$")
# Out:
# Emma Earned...
# 84 $
# Emma earned this after applying loss
# 59 $
