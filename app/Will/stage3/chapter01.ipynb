# %% [markdown]
# # 🤖 Chapter 1: The Blueprint and the Robot
#
# Welcome! Today we will learn something new and exciting: **Classes and Objects**.
#
# Think about this:
# - A **class** is like a *blueprint* 🏗️
# - An **object** is the *real robot* built from that blueprint 🤖
#
# Let's learn step by step!

# %% [markdown]
# ## 🧠 What is a Class?
#
# A **class** is a plan or template.
#
# Example:
# - A robot factory has a blueprint
# - That blueprint describes what every robot should look like
#
# But the blueprint itself is NOT a robot!
#
# Let's create our first class 👇

# %%
# This is a class (a blueprint)
class Robot:
    pass  # pass means "nothing here yet"

# %% [markdown]
# ## 🤖 What is an Object?
#
# An **object** is a real robot made from the class.
#
# We can create (build) a robot using the class!

# %%
# Create a robot (object)
my_robot = Robot()

print("I built a robot!", my_robot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Create a robot (object)
# ----> 2 my_robot = Robot()
#       4 print("I built a robot!", my_robot)
#
# NameError: name 'Robot' is not defined

# %%
# Another example
class Dog:
    pass

macy = Dog()
mina = Dog()

print("I have two dogs!", macy, mina)
# Out:
# I have two dogs! <__main__.Dog object at 0x7f907019d0> <__main__.Dog object at 0x7f90700f50>

# %% [markdown]
# 👉 You just created your first robot object!
#
# We can create MANY robots from the same class:

# %%
robot1 = Robot()
robot2 = Robot()
robot3 = Robot()

print("Robot 1:", robot1)
print("Robot 2:", robot2)
print("Robot 3:", robot3)

# %% [markdown]
# ## 🎯 Key Idea
#
# - **Class = Blueprint 🏗️**
# - **Object = Real Robot 🤖**
#
# One class → many robots!

# %% [markdown]
# # 🧪 Practice Area
#
# Now it's your turn! Complete the code below.
#
# 👉 Step 1: Create a class called `DogRobot`
# 👉 Step 2: Create TWO robot objects from it
# 👉 Step 3: Print them

# %%
# TODO: Create a class called DogRobot
class DogRobot:
    pass
robot1=DogRobot()
robot2=DogRobot()
print(robot1,robot2)
# TODO: Create two objects


# TODO: Print them
# Out:
# <__main__.DogRobot object at 0x7f906fd790> <__main__.DogRobot object at 0x7f906fe410>

# %% [markdown]
# 💡 Hint:
# - Use `class DogRobot:`
# - Use `DogRobot()` to create objects

# %% [markdown]
# # 🏠 Homework
#
# 🎯 Challenge: Build Your Own Robot Team!
#
# Write your own program:
#
# 1. Create a class called `TeamRobot`
# 2. Create at least **3 robot objects**
# 3. Print a message like:
#    - "My robot team is ready!"
#    - Print each robot
#
# ✨ Bonus (optional):
# - Create another class with a fun name (e.g., `SuperRobot`, `NinjaRobot`)
# - Create objects from it too!
#
# Have fun building your robot army 🤖🤖🤖!

# %%
class TeamRobot:
    pass
robot1=TeamRobot()
robot2=TeamRobot()
robot3=TeamRobot()
print("My robot team is ready! YAY!",robot1,robot2,robot3)
class U_R_Education:
    pass
member1=U_R_Education
member2=U_R_Education()
member3=U_R_Education()
member4=U_R_Education()
member5=U_R_Education()
member6=U_R_Education()
member7=U_R_Education()
member8=U_R_Education()
member9=U_R_Education()
member10=U_R_Education()
member11=U_R_Education()
member12=U_R_Education()
member13=U_R_Education()
member14=U_R_Education()
member15=U_R_Education()
member16=U_R_Education()
member17=U_R_Education()
member18=U_R_Education()
member19=U_R_Education()
member20=U_R_Education()
member21=U_R_Education()
member22=U_R_Education()
member23=U_R_Education()
member24=U_R_Education()
member25=U_R_Education()
member26=U_R_Education()
member27=U_R_Education()
member28=U_R_Education()
member29=U_R_Education()
member30=U_R_Education()
member31=U_R_Education()
member32=U_R_Education()
member33=U_R_Education()
member34=U_R_Education()
member35=U_R_Education()
member36=U_R_Education()
member37=U_R_Education()
member38=U_R_Education()
member39=U_R_Education()
member40=U_R_Education()
member41=U_R_Education()
member42=U_R_Education()
member43=U_R_Education()
member44=U_R_Education()
member45=U_R_Education()
member46=U_R_Education()
member47=U_R_Education()
member48=U_R_Education()
member49=U_R_Education()
member50=U_R_Education()
member51=U_R_Education()
member52=U_R_Education()
member53=U_R_Education()
member54=U_R_Education()
member55=U_R_Education()
member56=U_R_Education()
member57=U_R_Education()
member58=U_R_Education()
member59=U_R_Education()
member60=U_R_Education()
member61=U_R_Education()
member62=U_R_Education()
member63=U_R_Education()
member64=U_R_Education()
member65=U_R_Education()
member66=U_R_Education()
member67=U_R_Education()
member68=U_R_Education()
member69=U_R_Education()
member70=U_R_Education()
member71=U_R_Education()
member72=U_R_Education()
member73=U_R_Education()
member74=U_R_Education()
member75=U_R_Education()
member76=U_R_Education()
member77=U_R_Education()
member78=U_R_Education()
member79=U_R_Education()
member80=U_R_Education()
member81=U_R_Education()
member82=U_R_Education()
member83=U_R_Education()
member84=U_R_Education()
member85=U_R_Education()
member86=U_R_Education()
member87=U_R_Education()
member88=U_R_Education()
member89=U_R_Education()
member90=U_R_Education()
member91=U_R_Education()
member92=U_R_Education()
member93=U_R_Education()
member94=U_R_Education()
member95=U_R_Education()
member96=U_R_Education()
member97=U_R_Education()
member98=U_R_Education()
member99=U_R_Education()
member100=U_R_Education()
member101=U_R_Education()
member102=U_R_Education()
member103=U_R_Education()
member104=U_R_Education()
member105=U_R_Education()
member106=U_R_Education()
member107=U_R_Education()
member108=U_R_Education()
member109=U_R_Education()
member110=U_R_Education()
member111=U_R_Education()
member112=U_R_Education()
member113=U_R_Education()
member114=U_R_Education()
member115=U_R_Education()
member116=U_R_Education()
member117=U_R_Education()
member118=U_R_Education()
member119=U_R_Education()
member120=U_R_Education()
member121=U_R_Education()
member122=U_R_Education()
member123=U_R_Education()
member124=U_R_Education()
member125=U_R_Education()
member126=U_R_Education()
member127=U_R_Education()
member128=U_R_Education()
member129=U_R_Education()
member130=U_R_Education()
member131=U_R_Education()
member132=U_R_Education()
member133=U_R_Education()
member134=U_R_Education()
member135=U_R_Education()
member136=U_R_Education()
member137=U_R_Education()
member138=U_R_Education()
member139=U_R_Education()
member140=U_R_Education()
member141=U_R_Education()
member142=U_R_Education()
member143=U_R_Education()
member144=U_R_Education()
member145=U_R_Education()
member146=U_R_Education()
member147=U_R_Education()
member148=U_R_Education()
member149=U_R_Education()
member150=U_R_Education()
member151=U_R_Education()
member152=U_R_Education()
member153=U_R_Education()
member154=U_R_Education()
member155=U_R_Education()
member156=U_R_Education()
member157=U_R_Education()
member158=U_R_Education()
member159=U_R_Education()
member160=U_R_Education()
member161=U_R_Education()
member162=U_R_Education()
member163=U_R_Education()
member164=U_R_Education()
member165=U_R_Education()
member166=U_R_Education()
member167=U_R_Education()
member168=U_R_Education()
member169=U_R_Education()
member170=U_R_Education()
member171=U_R_Education()
member172=U_R_Education()
member173=U_R_Education()
member174=U_R_Education()
member175=U_R_Education()
member176=U_R_Education()
member177=U_R_Education()
member178=U_R_Education()
member179=U_R_Education()
member180=U_R_Education()
member181=U_R_Education()
member182=U_R_Education()
member183=U_R_Education()
member184=U_R_Education()
member185=U_R_Education()
member186=U_R_Education()
member187=U_R_Education()
member188=U_R_Education()
member189=U_R_Education()
member190=U_R_Education()
member191=U_R_Education()
member192=U_R_Education()
member193=U_R_Education()
member194=U_R_Education()
member195=U_R_Education()
member196=U_R_Education()
member197=U_R_Education()
member198=U_R_Education()
member199=U_R_Education()
member200=U_R_Education()
member201=U_R_Education()
member202=U_R_Education()
member203=U_R_Education()
member204=U_R_Education()
member205=U_R_Education()
member206=U_R_Education()
member207=U_R_Education()
member208=U_R_Education()
member209=U_R_Education()
member210=U_R_Education()
member211=U_R_Education()
member212=U_R_Education()
member213=U_R_Education()
member214=U_R_Education()
member215=U_R_Education()
member216=U_R_Education()
member217=U_R_Education()
member218=U_R_Education()
member219=U_R_Education()
member220=U_R_Education()
member221=U_R_Education()
member222=U_R_Education()
member223=U_R_Education()
member224=U_R_Education()
member225=U_R_Education()
member226=U_R_Education()
member227=U_R_Education()
member228=U_R_Education()
member229=U_R_Education()
member230=U_R_Education()
member231=U_R_Education()
member232=U_R_Education()
member233=U_R_Education()
member234=U_R_Education()
member235=U_R_Education()
member236=U_R_Education()
member237=U_R_Education()
member238=U_R_Education()
member239=U_R_Education()
member240=U_R_Education()
member241=U_R_Education()
member242=U_R_Education()
member243=U_R_Education()
member244=U_R_Education()
member245=U_R_Education()
member246=U_R_Education()
member247=U_R_Education()
member248=U_R_Education()
member249=U_R_Education()
member250=U_R_Education()
member251=U_R_Education()
member252=U_R_Education()
member253=U_R_Education()
member254=U_R_Education()
member255=U_R_Education()
member256=U_R_Education()
member257=U_R_Education()
member258=U_R_Education()
member259=U_R_Education()
member260=U_R_Education()
member261=U_R_Education()
member262=U_R_Education()
member263=U_R_Education()
member264=U_R_Education()
member265=U_R_Education()
member266=U_R_Education()
member267=U_R_Education()
member268=U_R_Education()
member269=U_R_Education()
member270=U_R_Education()
member271=U_R_Education()
member272=U_R_Education()
member273=U_R_Education()
member274=U_R_Education()
member275=U_R_Education()
member276=U_R_Education()
member277=U_R_Education()
member278=U_R_Education()
member279=U_R_Education()
member280=U_R_Education()
member281=U_R_Education()
member282=U_R_Education()
member283=U_R_Education()
member284=U_R_Education()
member285=U_R_Education()
member286=U_R_Education()
member287=U_R_Education()
member288=U_R_Education()
member289=U_R_Education()
member290=U_R_Education()
member291=U_R_Education()
member292=U_R_Education()
member293=U_R_Education()
member294=U_R_Education()
member295=U_R_Education()
member296=U_R_Education()
member297=U_R_Education()
member298=U_R_Education()
member299=U_R_Education()
member300=U_R_Education()
member301=U_R_Education()
member302=U_R_Education()
member303=U_R_Education()
member304=U_R_Education()
member305=U_R_Education()
member306=U_R_Education()
member307=U_R_Education()
member308=U_R_Education()
member309=U_R_Education()
member310=U_R_Education()
member311=U_R_Education()
member312=U_R_Education()
member313=U_R_Education()
member314=U_R_Education()
member315=U_R_Education()
member316=U_R_Education()
member317=U_R_Education()
member318=U_R_Education()
member319=U_R_Education()
member320=U_R_Education()
member321=U_R_Education()
member322=U_R_Education()
member323=U_R_Education()
member324=U_R_Education()
member325=U_R_Education()
member326=U_R_Education()
member327=U_R_Education()
member328=U_R_Education()
member329=U_R_Education()
member330=U_R_Education()
member331=U_R_Education()
member332=U_R_Education()
member333=U_R_Education()
member334=U_R_Education()
member335=U_R_Education()
member336=U_R_Education()
member337=U_R_Education()
member338=U_R_Education()
member339=U_R_Education()
member340=U_R_Education()
member341=U_R_Education()
member342=U_R_Education()
member343=U_R_Education()
member344=U_R_Education()
member345=U_R_Education()
member346=U_R_Education()
member347=U_R_Education()
member348=U_R_Education()
member349=U_R_Education()
member350=U_R_Education()
member351=U_R_Education()
member352=U_R_Education()
member353=U_R_Education()
member354=U_R_Education()
member355=U_R_Education()
member356=U_R_Education()
member357=U_R_Education()
member358=U_R_Education()
member359=U_R_Education()
member360=U_R_Education()
member361=U_R_Education()
member362=U_R_Education()
member363=U_R_Education()
member364=U_R_Education()
member365=U_R_Education()
member366=U_R_Education()
member367=U_R_Education()
member368=U_R_Education()
member369=U_R_Education()
member370=U_R_Education()
member371=U_R_Education()
member372=U_R_Education()
member373=U_R_Education()
member374=U_R_Education()
member375=U_R_Education()
member376=U_R_Education()
member377=U_R_Education()
member378=U_R_Education()
member379=U_R_Education()
member380=U_R_Education()
member381=U_R_Education()
member382=U_R_Education()
member383=U_R_Education()
member384=U_R_Education()
member385=U_R_Education()
member386=U_R_Education()
member387=U_R_Education()
member388=U_R_Education()
member389=U_R_Education()
member390=U_R_Education()
member391=U_R_Education()
member392=U_R_Education()
member393=U_R_Education()
member394=U_R_Education()
member395=U_R_Education()
member396=U_R_Education()
member397=U_R_Education()
member398=U_R_Education()
member399=U_R_Education()
member400=U_R_Education()
member401=U_R_Education()
member402=U_R_Education()
member403=U_R_Education()
member404=U_R_Education()
member405=U_R_Education()
member406=U_R_Education()
member407=U_R_Education()
member408=U_R_Education()
member409=U_R_Education()
member410=U_R_Education()
member411=U_R_Education()
member412=U_R_Education()
member413=U_R_Education()
member414=U_R_Education()
member415=U_R_Education()
member416=U_R_Education()
member417=U_R_Education()
member418=U_R_Education()
member419=U_R_Education()
member420=U_R_Education()
member421=U_R_Education()
member422=U_R_Education()
member423=U_R_Education()
member424=U_R_Education()
member425=U_R_Education()
member426=U_R_Education()
member427=U_R_Education()
member428=U_R_Education()
member429=U_R_Education()
member430=U_R_Education()
member431=U_R_Education()
member432=U_R_Education()
member433=U_R_Education()
member434=U_R_Education()
member435=U_R_Education()
member436=U_R_Education()
member437=U_R_Education()
member438=U_R_Education()
member439=U_R_Education()
member440=U_R_Education()
member441=U_R_Education()
member442=U_R_Education()
member443=U_R_Education()
member444=U_R_Education()
member445=U_R_Education()
member446=U_R_Education()
member447=U_R_Education()
member448=U_R_Education()
member449=U_R_Education()
member450=U_R_Education()
member451=U_R_Education()
member452=U_R_Education()
member453=U_R_Education()
member454=U_R_Education()
member455=U_R_Education()
member456=U_R_Education()
member457=U_R_Education()
member458=U_R_Education()
member459=U_R_Education()
member460=U_R_Education()
member461=U_R_Education()
member462=U_R_Education()
member463=U_R_Education()
member464=U_R_Education()
member465=U_R_Education()
member466=U_R_Education()
member467=U_R_Education()
member468=U_R_Education()
member469=U_R_Education()
member470=U_R_Education()
member471=U_R_Education()
member472=U_R_Education()
member473=U_R_Education()
member474=U_R_Education()
member475=U_R_Education()
member476=U_R_Education()
member477=U_R_Education()
member478=U_R_Education()
member479=U_R_Education()
member480=U_R_Education()
member481=U_R_Education()
member482=U_R_Education()
member483=U_R_Education()
member484=U_R_Education()
member485=U_R_Education()
member486=U_R_Education()
member487=U_R_Education()
member488=U_R_Education()
member489=U_R_Education()
member490=U_R_Education()
member491=U_R_Education()
member492=U_R_Education()
member493=U_R_Education()
member494=U_R_Education()
member495=U_R_Education()
member496=U_R_Education()
member497=U_R_Education()
member498=U_R_Education()
member499=U_R_Education()
member500=U_R_Education()
member501=U_R_Education()
member502=U_R_Education()
member503=U_R_Education()
member504=U_R_Education()
member505=U_R_Education()
member506=U_R_Education()
member507=U_R_Education()
member508=U_R_Education()
member509=U_R_Education()
member510=U_R_Education()
member511=U_R_Education()
member512=U_R_Education()
member513=U_R_Education()
member514=U_R_Education()
member515=U_R_Education()
member516=U_R_Education()
member517=U_R_Education()
member518=U_R_Education()
member519=U_R_Education()
member520=U_R_Education()
member521=U_R_Education()
member522=U_R_Education()
member523=U_R_Education()
member524=U_R_Education()
member525=U_R_Education()
member526=U_R_Education()
member527=U_R_Education()
member528=U_R_Education()
member529=U_R_Education()
member530=U_R_Education()
member531=U_R_Education()
member532=U_R_Education()
member533=U_R_Education()
member534=U_R_Education()
member535=U_R_Education()
member536=U_R_Education()
member537=U_R_Education()
member538=U_R_Education()
member539=U_R_Education()
member540=U_R_Education()
member541=U_R_Education()
member542=U_R_Education()
member543=U_R_Education()
member544=U_R_Education()
member545=U_R_Education()
member546=U_R_Education()
member547=U_R_Education()
member548=U_R_Education()
member549=U_R_Education()
member550=U_R_Education()
member551=U_R_Education()
member552=U_R_Education()
member553=U_R_Education()
member554=U_R_Education()
member555=U_R_Education()
member556=U_R_Education()
member557=U_R_Education()
member558=U_R_Education()
member559=U_R_Education()
member560=U_R_Education()
member561=U_R_Education()
member562=U_R_Education()
member563=U_R_Education()
member564=U_R_Education()
member565=U_R_Education()
member566=U_R_Education()
member567=U_R_Education()
member568=U_R_Education()
member569=U_R_Education()
member570=U_R_Education()
member571=U_R_Education()
member572=U_R_Education()
member573=U_R_Education()
member574=U_R_Education()
member575=U_R_Education()
member576=U_R_Education()
member577=U_R_Education()
member578=U_R_Education()
member579=U_R_Education()
member580=U_R_Education()
member581=U_R_Education()
member582=U_R_Education()
member583=U_R_Education()
member584=U_R_Education()
member585=U_R_Education()
member586=U_R_Education()
member587=U_R_Education()
member588=U_R_Education()
member589=U_R_Education()
member590=U_R_Education()
member591=U_R_Education()
member592=U_R_Education()
member593=U_R_Education()
member594=U_R_Education()
member595=U_R_Education()
member596=U_R_Education()
member597=U_R_Education()
member598=U_R_Education()
member599=U_R_Education()
member600=U_R_Education()
member601=U_R_Education()
member602=U_R_Education()
member603=U_R_Education()
member604=U_R_Education()
member605=U_R_Education()
member606=U_R_Education()
member607=U_R_Education()
member608=U_R_Education()
member609=U_R_Education()
member610=U_R_Education()
member611=U_R_Education()
member612=U_R_Education()
member613=U_R_Education()
member614=U_R_Education()
member615=U_R_Education()
member616=U_R_Education()
member617=U_R_Education()
member618=U_R_Education()
member619=U_R_Education()
member620=U_R_Education()
member621=U_R_Education()
member622=U_R_Education()
member623=U_R_Education()
member624=U_R_Education()
member625=U_R_Education()
member626=U_R_Education()
member627=U_R_Education()
member628=U_R_Education()
member629=U_R_Education()
member630=U_R_Education()
member631=U_R_Education()
member632=U_R_Education()
member633=U_R_Education()
member634=U_R_Education()
member635=U_R_Education()
member636=U_R_Education()
member637=U_R_Education()
member638=U_R_Education()
member639=U_R_Education()
member640=U_R_Education()
member641=U_R_Education()
member642=U_R_Education()
member643=U_R_Education()
member644=U_R_Education()
member645=U_R_Education()
member646=U_R_Education()
member647=U_R_Education()
member648=U_R_Education()
member649=U_R_Education()
member650=U_R_Education()
member651=U_R_Education()
member652=U_R_Education()
member653=U_R_Education()
member654=U_R_Education()
member655=U_R_Education()
member656=U_R_Education()
member657=U_R_Education()
member658=U_R_Education()
member659=U_R_Education()
member660=U_R_Education()
member661=U_R_Education()
member662=U_R_Education()
member663=U_R_Education()
member664=U_R_Education()
member665=U_R_Education()
member666=U_R_Education()
member667=U_R_Education()
member668=U_R_Education()
member669=U_R_Education()
member670=U_R_Education()
member671=U_R_Education()
member672=U_R_Education()
member673=U_R_Education()
member674=U_R_Education()
member675=U_R_Education()
member676=U_R_Education()
member677=U_R_Education()
member678=U_R_Education()
member679=U_R_Education()
member680=U_R_Education()
member681=U_R_Education()
member682=U_R_Education()
member683=U_R_Education()
member684=U_R_Education()
member685=U_R_Education()
member686=U_R_Education()
member687=U_R_Education()
member688=U_R_Education()
member689=U_R_Education()
member690=U_R_Education()
member691=U_R_Education()
member692=U_R_Education()
member693=U_R_Education()
member694=U_R_Education()
member695=U_R_Education()
member696=U_R_Education()
member697=U_R_Education()
member698=U_R_Education()
member699=U_R_Education()
member700=U_R_Education()
member701=U_R_Education()
member702=U_R_Education()
member703=U_R_Education()
member704=U_R_Education()
member705=U_R_Education()
member706=U_R_Education()
member707=U_R_Education()
member708=U_R_Education()
member709=U_R_Education()
member710=U_R_Education()
member711=U_R_Education()
member712=U_R_Education()
member713=U_R_Education()
member714=U_R_Education()
member715=U_R_Education()
member716=U_R_Education()
member717=U_R_Education()
member718=U_R_Education()
member719=U_R_Education()
member720=U_R_Education()
member721=U_R_Education()
member722=U_R_Education()
member723=U_R_Education()
member724=U_R_Education()
member725=U_R_Education()
member726=U_R_Education()
member727=U_R_Education()
member728=U_R_Education()
member729=U_R_Education()
member730=U_R_Education()
member731=U_R_Education()
member732=U_R_Education()
member733=U_R_Education()
member734=U_R_Education()
member735=U_R_Education()
member736=U_R_Education()
member737=U_R_Education()
member738=U_R_Education()
member739=U_R_Education()
member740=U_R_Education()
member741=U_R_Education()
member742=U_R_Education()
member743=U_R_Education()
member744=U_R_Education()
member745=U_R_Education()
member746=U_R_Education()
member747=U_R_Education()
member748=U_R_Education()
member749=U_R_Education()
member750=U_R_Education()
member751=U_R_Education()
member752=U_R_Education()
member753=U_R_Education()
member754=U_R_Education()
member755=U_R_Education()
member756=U_R_Education()
member757=U_R_Education()
member758=U_R_Education()
member759=U_R_Education()
member760=U_R_Education()
member761=U_R_Education()
member762=U_R_Education()
member763=U_R_Education()
member764=U_R_Education()
member765=U_R_Education()
member766=U_R_Education()
member767=U_R_Education()
member768=U_R_Education()
member769=U_R_Education()
member770=U_R_Education()
member771=U_R_Education()
member772=U_R_Education()
member773=U_R_Education()
member774=U_R_Education()
member775=U_R_Education()
member776=U_R_Education()
member777=U_R_Education()
member778=U_R_Education()
member779=U_R_Education()
member780=U_R_Education()
member781=U_R_Education()
member782=U_R_Education()
member783=U_R_Education()
member784=U_R_Education()
member785=U_R_Education()
member786=U_R_Education()
member787=U_R_Education()
member788=U_R_Education()
member789=U_R_Education()
member790=U_R_Education()
member791=U_R_Education()
member792=U_R_Education()
member793=U_R_Education()
member794=U_R_Education()
member795=U_R_Education()
member796=U_R_Education()
member797=U_R_Education()
member798=U_R_Education()
member799=U_R_Education()
member800=U_R_Education()
member801=U_R_Education()
member802=U_R_Education()
member803=U_R_Education()
member804=U_R_Education()
member805=U_R_Education()
member806=U_R_Education()
member807=U_R_Education()
member808=U_R_Education()
member809=U_R_Education()
member810=U_R_Education()
member811=U_R_Education()
member812=U_R_Education()
member813=U_R_Education()
member814=U_R_Education()
member815=U_R_Education()
member816=U_R_Education()
member817=U_R_Education()
member818=U_R_Education()
member819=U_R_Education()
member820=U_R_Education()
member821=U_R_Education()
member822=U_R_Education()
member823=U_R_Education()
member824=U_R_Education()
member825=U_R_Education()
member826=U_R_Education()
member827=U_R_Education()
member828=U_R_Education()
member829=U_R_Education()
member830=U_R_Education()
member831=U_R_Education()
member832=U_R_Education()
member833=U_R_Education()
member834=U_R_Education()
member835=U_R_Education()
member836=U_R_Education()
member837=U_R_Education()
member838=U_R_Education()
member839=U_R_Education()
member840=U_R_Education()
member841=U_R_Education()
member842=U_R_Education()
member843=U_R_Education()
member844=U_R_Education()
member845=U_R_Education()
member846=U_R_Education()
member847=U_R_Education()
member848=U_R_Education()
member849=U_R_Education()
member850=U_R_Education()
member851=U_R_Education()
member852=U_R_Education()
member853=U_R_Education()
member854=U_R_Education()
member855=U_R_Education()
member856=U_R_Education()
member857=U_R_Education()
member858=U_R_Education()
member859=U_R_Education()
member860=U_R_Education()
member861=U_R_Education()
member862=U_R_Education()
member863=U_R_Education()
member864=U_R_Education()
member865=U_R_Education()
member866=U_R_Education()
member867=U_R_Education()
member868=U_R_Education()
member869=U_R_Education()
member870=U_R_Education()
member871=U_R_Education()
member872=U_R_Education()
member873=U_R_Education()
member874=U_R_Education()
member875=U_R_Education()
member876=U_R_Education()
member877=U_R_Education()
member878=U_R_Education()
member879=U_R_Education()
member880=U_R_Education()
member881=U_R_Education()
member882=U_R_Education()
member883=U_R_Education()
member884=U_R_Education()
member885=U_R_Education()
member886=U_R_Education()
member887=U_R_Education()
member888=U_R_Education()
member889=U_R_Education()
member890=U_R_Education()
member891=U_R_Education()
member892=U_R_Education()
member893=U_R_Education()
member894=U_R_Education()
member895=U_R_Education()
member896=U_R_Education()
member897=U_R_Education()
member898=U_R_Education()
member899=U_R_Education()
member900=U_R_Education()
member901=U_R_Education()
member902=U_R_Education()
member903=U_R_Education()
member904=U_R_Education()
member905=U_R_Education()
member906=U_R_Education()
member907=U_R_Education()
member908=U_R_Education()
member909=U_R_Education()
member910=U_R_Education()
member911=U_R_Education()
member912=U_R_Education()
member913=U_R_Education()
member914=U_R_Education()
member915=U_R_Education()
member916=U_R_Education()
member917=U_R_Education()
member918=U_R_Education()
member919=U_R_Education()
member920=U_R_Education()
member921=U_R_Education()
member922=U_R_Education()
member923=U_R_Education()
member924=U_R_Education()
member925=U_R_Education()
member926=U_R_Education()
member927=U_R_Education()
member928=U_R_Education()
member929=U_R_Education()
member930=U_R_Education()
member931=U_R_Education()
member932=U_R_Education()
member933=U_R_Education()
member934=U_R_Education()
member935=U_R_Education()
member936=U_R_Education()
member937=U_R_Education()
member938=U_R_Education()
member939=U_R_Education()
member940=U_R_Education()
member941=U_R_Education()
member942=U_R_Education()
member943=U_R_Education()
member944=U_R_Education()
member945=U_R_Education()
member946=U_R_Education()
member947=U_R_Education()
member948=U_R_Education()
member949=U_R_Education()
member950=U_R_Education()
member951=U_R_Education()
member952=U_R_Education()
member953=U_R_Education()
member954=U_R_Education()
member955=U_R_Education()
member956=U_R_Education()
member957=U_R_Education()
member958=U_R_Education()
member959=U_R_Education()
member960=U_R_Education()
member961=U_R_Education()
member962=U_R_Education()
member963=U_R_Education()
member964=U_R_Education()
member965=U_R_Education()
member966=U_R_Education()
member967=U_R_Education()
member968=U_R_Education()
member969=U_R_Education()
member970=U_R_Education()
member971=U_R_Education()
member972=U_R_Education()
member973=U_R_Education()
member974=U_R_Education()
member975=U_R_Education()
member976=U_R_Education()
member977=U_R_Education()
member978=U_R_Education()
member979=U_R_Education()
member980=U_R_Education()
member981=U_R_Education()
member982=U_R_Education()
member983=U_R_Education()
member984=U_R_Education()
member985=U_R_Education()
member986=U_R_Education()
member987=U_R_Education()
member988=U_R_Education()
member989=U_R_Education()
member990=U_R_Education()
member991=U_R_Education()
member992=U_R_Education()
member993=U_R_Education()
member994=U_R_Education()
member995=U_R_Education()
member996=U_R_Education()
member997=U_R_Education()
member998=U_R_Education()
member999=U_R_Education()
member1000=U_R_Education()
print("U.R Education team Includes",member1,member2,member3,member4,member5,member6,member7,member8,member9,member10,member11,member12,member13,member14,member15,member16,member17,member18,member19,member20,member21,member22,member23,member24,member25,member26,member27,member28,member29,member30,member31,member32,member33,member34,member35,member36,member37,member38,member39,member40,member41,member42,member43,member44,member45,member46,member47,member48,member49,member50,member51,member52,member53,member54,member55,member56,member57,member58,member59,member60,member61,member62,member63,member64,member65,member66,member67,member68,member69,member70,member71,member72,member73,member74,member75,member76,member77,member78,member79,member80,member81,member82,member83,member84,member85,member86,member87,member88,member89,member90,member91,member92,member93,member94,member95,member96,member97,member98,member99,member100,member101,member102,member103,member104,member105,member106,member107,member108,member109,member110,member111,member112,member113,member114,member115,member116,member117,member118,member119,member120,member121,member122,member123,member124,member125,member126,member127,member128,member129,member130,member131,member132,member133,member134,member135,member136,member137,member138,member139,member140,member141,member142,member143,member144,member145,member146,member147,member148,member149,member150,member151,member152,member153,member154,member155,member156,member157,member158,member159,member160,member161,member162,member163,member164,member165,member166,member167,member168,member169,member170,member171,member172,member173,member174,member175,member176,member177,member178,member179,member180,member181,member182,member183,member184,member185,member186,member187,member188,member189,member190,member191,member192,member193,member194,member195,member196,member197,member198,member199,member200,member201,member202,member203,member204,member205,member206,member207,member208,member209,member210,member211,member212,member213,member214,member215,member216,member217,member218,member219,member220,member221,member222,member223,member224,member225,member226,member227,member228,member229,member230,member231,member232,member233,member234,member235,member236,member237,member238,member239,member240,member241,member242,member243,member244,member245,member246,member247,member248,member249,member250,member251,member252,member253,member254,member255,member256,member257,member258,member259,member260,member261,member262,member263,member264,member265,member266,member267,member268,member269,member270,member271,member272,member273,member274,member275,member276,member277,member278,member279,member280,member281,member282,member283,member284,member285,member286,member287,member288,member289,member290,member291,member292,member293,member294,member295,member296,member297,member298,member299,member300,member301,member302,member303,member304,member305,member306,member307,member308,member309,member310,member311,member312,member313,member314,member315,member316,member317,member318,member319,member320,member321,member322,member323,member324,member325,member326,member327,member328,member329,member330,member331,member332,member333,member334,member335,member336,member337,member338,member339,member340,member341,member342,member343,member344,member345,member346,member347,member348,member349,member350,member351,member352,member353,member354,member355,member356,member357,member358,member359,member360,member361,member362,member363,member364,member365,member366,member367,member368,member369,member370,member371,member372,member373,member374,member375,member376,member377,member378,member379,member380,member381,member382,member383,member384,member385,member386,member387,member388,member389,member390,member391,member392,member393,member394,member395,member396,member397,member398,member399,member400,member401,member402,member403,member404,member405,member406,member407,member408,member409,member410,member411,member412,member413,member414,member415,member416,member417,member418,member419,member420,member421,member422,member423,member424,member425,member426,member427,member428,member429,member430,member431,member432,member433,member434,member435,member436,member437,member438,member439,member440,member441,member442,member443,member444,member445,member446,member447,member448,member449,member450,member451,member452,member453,member454,member455,member456,member457,member458,member459,member460,member461,member462,member463,member464,member465,member466,member467,member468,member469,member470,member471,member472,member473,member474,member475,member476,member477,member478,member479,member480,member481,member482,member483,member484,member485,member486,member487,member488,member489,member490,member491,member492,member493,member494,member495,member496,member497,member498,member499,member500,member501,member502,member503,member504,member505,member506,member507,member508,member509,member510,member511,member512,member513,member514,member515,member516,member517,member518,member519,member520,member521,member522,member523,member524,member525,member526,member527,member528,member529,member530,member531,member532,member533,member534,member535,member536,member537,member538,member539,member540,member541,member542,member543,member544,member545,member546,member547,member548,member549,member550,member551,member552,member553,member554,member555,member556,member557,member558,member559,member560,member561,member562,member563,member564,member565,member566,member567,member568,member569,member570,member571,member572,member573,member574,member575,member576,member577,member578,member579,member580,member581,member582,member583,member584,member585,member586,member587,member588,member589,member590,member591,member592,member593,member594,member595,member596,member597,member598,member599,member600,member601,member602,member603,member604,member605,member606,member607,member608,member609,member610,member611,member612,member613,member614,member615,member616,member617,member618,member619,member620,member621,member622,member623,member624,member625,member626,member627,member628,member629,member630,member631,member632,member633,member634,member635,member636,member637,member638,member639,member640,member641,member642,member643,member644,member645,member646,member647,member648,member649,member650,member651,member652,member653,member654,member655,member656,member657,member658,member659,member660,member661,member662,member663,member664,member665,member666,member667,member668,member669,member670,member671,member672,member673,member674,member675,member676,member677,member678,member679,member680,member681,member682,member683,member684,member685,member686,member687,member688,member689,member690,member691,member692,member693,member694,member695,member696,member697,member698,member699,member700,member701,member702,member703,member704,member705,member706,member707,member708,member709,member710,member711,member712,member713,member714,member715,member716,member717,member718,member719,member720,member721,member722,member723,member724,member725,member726,member727,member728,member729,member730,member731,member732,member733,member734,member735,member736,member737,member738,member739,member740,member741,member742,member743,member744,member745,member746,member747,member748,member749,member750,member751,member752,member753,member754,member755,member756,member757,member758,member759,member760,member761,member762,member763,member764,member765,member766,member767,member768,member769,member770,member771,member772,member773,member774,member775,member776,member777,member778,member779,member780,member781,member782,member783,member784,member785,member786,member787,member788,member789,member790,member791,member792,member793,member794,member795,member796,member797,member798,member799,member800,member801,member802,member803,member804,member805,member806,member807,member808,member809,member810,member811,member812,member813,member814,member815,member816,member817,member818,member819,member820,member821,member822,member823,member824,member825,member826,member827,member828,member829,member830,member831,member832,member833,member834,member835,member836,member837,member838,member839,member840,member841,member842,member843,member844,member845,member846,member847,member848,member849,member850,member851,member852,member853,member854,member855,member856,member857,member858,member859,member860,member861,member862,member863,member864,member865,member866,member867,member868,member869,member870,member871,member872,member873,member874,member875,member876,member877,member878,member879,member880,member881,member882,member883,member884,member885,member886,member887,member888,member889,member890,member891,member892,member893,member894,member895,member896,member897,member898,member899,member900,member901,member902,member903,member904,member905,member906,member907,member908,member909,member910,member911,member912,member913,member914,member915,member916,member917,member918,member919,member920,member921,member922,member923,member924,member925,member926,member927,member928,member929,member930,member931,member932,member933,member934,member935,member936,member937,member938,member939,member940,member941,member942,member943,member944,member945,member946,member947,member948,member949,member950,member951,member952,member953,member954,member955,member956,member957,member958,member959,member960,member961,member962,member963,member964,member965,member966,member967,member968,member969,member970,member971,member972,member973,member974,member975,member976,member977,member978,member979,member980,member981,member982,member983,member984,member985,member986,member987,member988,member989,member990,member991,member992,member993,member994,member995,member996,member997,member998,member999,member1000)
# Out:
# My robot team is ready! YAY! <__main__.TeamRobot object at 0x7f9058ce10> <__main__.TeamRobot object at 0x7f9058d410> <__main__.TeamRobot object at 0x7f90728690>
# ...

# %%
for i in range(1000):
    print("member"+str(i)+"=U_R_Education()")
# Out:
# member0=U_R_Education()
# member1=U_R_Education()
# member2=U_R_Education()
# member3=U_R_Education()
# member4=U_R_Education()
# member5=U_R_Education()
# member6=U_R_Education()
# member7=U_R_Education()
# member8=U_R_Education()
# member9=U_R_Education()
# member10=U_R_Education()
# member11=U_R_Education()
# member12=U_R_Education()
# member13=U_R_Education()
# member14=U_R_Education()
# member15=U_R_Education()
# member16=U_R_Education()
# member17=U_R_Education()
# member18=U_R_Education()
# member19=U_R_Education()
# member20=U_R_Education()
# member21=U_R_Education()
# member22=U_R_Education()
# member23=U_R_Education()
# member24=U_R_Education()
# member25=U_R_Education()
# member26=U_R_Education()
# member27=U_R_Education()
# member28=U_R_Education()
# member29=U_R_Education()
# member30=U_R_Education()
# member31=U_R_Education()
# member32=U_R_Education()
# member33=U_R_Education()
# member34=U_R_Education()
# member35=U_R_Education()
# member36=U_R_Education()
# ...

# %%
for i in range(1001):
    print(",member"+str(i),end="")
# Out:
# ,member0,member1,member2,member3,member4,member5,member6,member7,member8,member9,member10,member11,member12,member13,member14,member15,member16,member17,member18,member19,member20,member21,member22,member23,member24,member25,member26,member27,member28,member29,member30,member31,member32,member33,member34,member35,member36,member37,member38,member39,member40,member41,member42,member43,member44,member45,member46,member47,member48,member49,member50,member51,member52,member53,member54,member55,member56,member57,member58,member59,member60,member61,member62,member63,member64,member65,member66,member67,member68,member69,member70,member71,member72,member73,member74,member75,member76,member77,member78,member79,member80,member81,member82,member83,member84,member85,member86,member87,member88,member89,member90,member91,member92,member93,member94,member95,member96,member97,member98,member99,member100,member101,member102,member103,member104,member105,member106,member107,member108,member109,member1
# ...
