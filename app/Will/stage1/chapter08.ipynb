# %% [markdown]
# # 📦 Chapter 8: Coding Shortcuts (Functions)
# ### Creating Your Own Blocks
# In VEX blocks, you can make "My Blocks." In Python, we call these **Functions**.
#
# A function is a way to group a bunch of code together and give it a name. This way, you don't have to write the same code over and over again.

# %% [markdown]
# ### How to Define a Function
# We use the keyword `def` (short for Define).
#
# **Example:**

# %%
# 1. DEFINE the function (This just memorizes the steps, it doesn't run them yet)
def cheer_for_team():
    print("Go Team!")
    print("You can do it!")
    print("VEX Robotics is cool!")

# 2. CALL the function (This actually runs the code)
cheer_for_team()

# %% [markdown]
# ### 🛠️ Robot Activity: "Macro Commands"
# **Your Mission:**
# Picking up a cube is complicated. It involves: Lowering the arm, Closing the claw, and Raising the arm.
# Let's create a shortcut for this!
#
# 1. Define a function called `pick_up_cube()`.
# 2. Inside, print these steps:
#    * "Lowering Arm..."
#    * "Closing Claw..."
#    * "Raising Arm..."
# 3. Now, **Call** the function twice (pretend there are two cubes).

# %%
# --- WRITE YOUR MISSION CODE BELOW ---
# 1. DEFINE the function (This just memorizes the steps, it doesn't run them yet)
def pick_up_cube():
    print("Lowering Arm...")
    print("Closing Claw...")
    print("Raising Arm...")

# 2. CALL the function (This actually runs the code)
pick_up_cube()
pick_up_cube()
# 1. Define the function


# 2. Call the function (Do it twice!)

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Drop Off:**
# Write a new function called `drop_cube()`. It should print the reverse steps (Lower Arm, Open Claw, Raise Arm).
# Then write a script that calls: `pick_up_cube()`, then `drop_cube()`.

# %%
# --- WRITE YOUR MISSION CODE BELOW ---
# 1. DEFINE the function (This just memorizes the steps, it doesn't run them yet)
def pick_up_cube():
    print("Lowering Arm...")
    print("Closing Claw...")
    print("Raising Arm...")
def drop_cube():
    print("Lowering Arm...")
    print("Opening Claw...")
    print("Raising Arm...")

# 2. CALL the function (This actually runs the code)
pick_up_cube()
drop_cube()
# 1. Define the function


# 2. Call the function (Do it twice!)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6     print("Raising Arm...")
#       8 # 2. CALL the function (This actually runs the code)
# ----> 9 pick_up_cube()
#      10 drop_cube()
#      11 # 1. Define the function
#      12
#      13
#      14 # 2. Call the function (Do it twice!)
#
# NameError: name 'pick_up_cube' is not defined
