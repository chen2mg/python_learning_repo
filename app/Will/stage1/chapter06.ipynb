# %% [markdown]
# # 🔄 Chapter 6: Doing it Again (For Loops)
# ### Don't Repeat Yourself!
# Imagine you want your robot to drive in a square. You could write:
# * `Drive Forward`
# * `Turn Right`
# * `Drive Forward`
# * `Turn Right`...
#
# That takes forever to type! Instead, we use a **For Loop** to tell the robot: **"Do this 4 times."**

# %% [markdown]
# ### The Range Command
# We use `range()` to tell the computer how many times to count.
#
# **Try running this code:**

# %%
# Repeat 3 times
print("Starting Loop...")

for number in range(3):
    print("Beep!")

print("Loop Finished!")

# %% [markdown]
# ### 🛠️ Robot Activity: "The Square Pattern"
# **Your Mission:**
# Teach the robot to drive in a perfect square. A square has 4 sides.
#
# 1. Write a `for` loop that repeats **4** times.
# 2. Inside the loop, print **"Moving Forward 200mm"**.
# 3. Also inside the loop, print **"Turning Right 90 degrees"**.
# 4. Watch the robot repeat your commands!

# %%
# --- WRITE YOUR MISSION CODE BELOW ---
for i in range(4):
    print("Moving Forward 200mm")
    print("Turning Right 90 degrees")
# 1. Create the loop (4 times)


# 2 & 3. Print the movement commands inside the loop

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Hexagon:**
# A hexagon has **6 sides**. Change the loop to run 6 times.
# Also, inside the loop, print the `number` variable so you can see which side the robot is currently on (Side 0, Side 1, etc.).

# %%
# --- WRITE YOUR MISSION CODE BELOW ---
import time
for i in range(1,7):
    print("Currently on Size "+str(i)+" Of the Hexagon")
    time.sleep(0.5)
# Out:
# Currently on Size 1 Of the Hexagon
# Currently on Size 2 Of the Hexagon
# Currently on Size 3 Of the Hexagon
# Currently on Size 4 Of the Hexagon
# Currently on Size 5 Of the Hexagon
# Currently on Size 6 Of the Hexagon
