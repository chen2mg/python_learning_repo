# %% [markdown]
# # 🤖 Chapter 1: Talking to your Computer
#
# ### Welcome, Robot Commander!
# Before we can make the robot move, we have to make sure it is "awake" and listening to us.
#
# Today, we are going to learn two superpowers:
# 1. **Print**: How to make the robot speak to us.
# 2. **Variables**: How to give the robot a memory.

# %% [markdown]
# ### Part 1: The Voice (Print)
# In Python, if you want the robot to say something on the screen, you use the command `print()`.
# Whatever you put inside the parentheses `( )` and quotes `" "` is what the robot will say.
#
# **Try running the code below:**

# %%
print("System booting up...")
print("Hello Commander! I am ready.")

# %%
print("china")
# Out:
# china

# %% [markdown]
# ### Part 2: The Memory (Variables)
# Robots need to remember things, like their name, what team they are on, or what color their lights should be. We use **Variables** to store this info.
#
# Think of a variable like a box with a label on it.
# * We create a box named `robot_name`.
# * We put the name `"VEX-1000"` inside it.

# %%
# Creating our variables (The Robot's Memory)
robot_name = "Box Huey"
team_number = "93328A"
brain_id = 99

# Now, let's print what is inside the memory
print("Robot Name:", robot_name)


print("Team ID:", team_number)
# Out:
# Robot Name: Box Huey
# Team ID: 93328A

# %% [markdown]
# ### 🛠️ Robot Activity: "The Bot-Check"
# **Your Mission:**
# It is time to boot up your robot for the first time! Write a script that sets up the robot's configuration and prints a "System Report" to the screen.
#
# 1. Create a variable called `port_number` and set it to `1`.
# 2. Create a variable called `indicator_color` and set it to `"Green"`.
# 3. Print a message that says: **"Checking Port..."** followed by the port number.
# 4. Print a message that says: **"System Light Color:"** followed by the color.

# %%
# --- WRITE YOUR MISSION CODE BELOW -

# 1. Create your variables here
port_number = 1
indicator_color = "Green"


# 2. Print your system report here
print("Checking Port...:", port_number)
print("System Light Color", indicator_color)
# Out:
# Checking Port...: 1
# System Light Color Green

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Upgrade:**
# Change the `indicator_color` variable to `"Red"` (maybe there is an error!) and change the `port_number` to `10`. Run your code again to see if the robot's report changes.

# %%
indicator_color = "Red"
port_number = 10

print("Checking Port...:", port_number)
print("System Light Color:", indicator_color)
# Out:
# Checking Port...: 10
# System Light Color: Red

# %%
cup = 3
saturday = "28 cups"
supplies = 25
money_made = cup * saturday 
money_earned = cup * saturday - supplies

print(money_made)
print(money_earned)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 supplies = 25
#       4 money_made = cup * saturday
# ----> 5 money_earned = cup * saturday - supplies
#       7 print(money_made)
#       8 print(money_earned)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
