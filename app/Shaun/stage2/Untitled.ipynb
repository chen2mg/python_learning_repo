# %%
cup_cost = 3
saturday_sold_cups = 28
money_made = cup_cost * saturday_sold_cups
profit = money_made - 25
print("Money made:", money_made)
print("Profit:", profit)
# Out:
# Money made: 84
# Profit: 59
