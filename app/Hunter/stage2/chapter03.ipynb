# %% [markdown]
# # 📦 Chapter 3: The Delicate Touch (Nested Ifs)
# ### Wheels within Wheels
# Sometimes, asking one question leads to another question.
# * **Question 1:** Do I see a ball? (If No, keep driving. If Yes, go to Q2).
# * **Question 2:** Is the ball Red or Blue?
#
# This is called **Nesting**. It means putting an `if` statement *inside* another `if` statement (like a Russian nesting doll).

# %%
see_ball = True
ball_color = "Blue"

if see_ball == True:
    print("I see a ball! Investigating...")
    
    # This check ONLY happens if see_ball is True
    if ball_color == "Red":
        print("It is the enemy! Attack!")
    else:
        print("It is friendly. Collect it.")
        
else:
    print("Scanning area... nothing found.")
# Out:
# I see a ball! Investigating...
# It is friendly. Collect it.

# %% [markdown]
# ### 🛠️ Robot Activity: "The Smart Claw"
# **Your Mission:**
# Your robot is picking up boxes. Some are heavy, some are light.
#
# 1.  Create `has_box` (True/False).
# 2.  Create `box_weight` (Integer).
# 3.  **Outer Check:** `if has_box` is True:
#     * Print "Holding Box."
#     * **Inner Check:** `if box_weight > 50`:
#         * Print "Heavy object! Using High Power Mode."
#     * **Inner Else:**
#         * Print "Light object. Using Normal Power."
# 4.  **Outer Else:** Print "Claw is empty."

# %%
# --- WRITE YOUR MISSION CODE BELOW ---

# 1. Setup variables
has_box = True
box_weight = 80

# 2. Write the Nested Logic
if has_box:
    print("Holding Box.")
    
    if box_weight > 50:
        print("Heavy object! Using High Power Mode.")
    else:
        print("Light object. Using Normal Power.")
else:
    print("Claw is empty.")
# Out:
# Holding Box.
# Heavy object! Using High Power Mode.

# %% [markdown]
# ### 🏠 Homework Challenge
# **The Maze Runner:**
# 1.  Check `if sensor_front < 50` (Wall ahead!).
# 2.  Inside that, check `if sensor_left > 200` (Left is open).
#     * Print "Turn Left".
# 3.  Else (Left is blocked too).
#     * Print "Turn Right".

# %%
sensor_front = 30
sensor_left = 250

if sensor_front < 50:
    print("Wall ahead!")
    
    if sensor_left > 200:
        print("Turn Left")
    else:
        print("Turn Right")
# Out:
# Wall ahead!
# Turn Left
